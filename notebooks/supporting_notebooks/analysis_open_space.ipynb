# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import os
LANDING_DATA_DIR = "../../data/landing"
RAW_DATA_DIR = "../../data/raw"
CURATED_DATA_DIR = "../../data/curated"

sf = gpd.read_file(
    f"{LANDING_DATA_DIR}/openspace_locations/VPA_Draft_Open_Space_data.shp")
sf
# Out:
#          FID         LGA     VM_PARCEL_ VM_PARCE_1               DATA_SOURC  \
# 0          1  BOROONDARA      3\LP28215      95086  VM Features of Interest
# 1          2  BOROONDARA     159\LP5481  203973157               VM Parcels
# 2          3  BOROONDARA      3\TP84208  203973089               VM Parcels
# 3          4  BOROONDARA      1\TP84208  203973073               VM Parcels
# 4          5  BOROONDARA     1\TP802753  203972979               VM Parcels
# ...      ...         ...            ...        ...                      ...
# 38805  38806   FRANKSTON            NaN        NaN        Frankston Council
# 38806  38807       YARRA      2\LP38905    2015149               VM Parcels
# 38807  38808   FRANKSTON        NO DATA    NO DATA          Melbourne Water
# 38808  38809   FRANKSTON       CP151911    1114997               VM Parcels
# 38809  38810   FRANKSTON  RES1\PS616669  211759478               VM Parcels
#
# ...

# %%
print(sf['OS_TYPE'].value_counts())
print(sf['OS_CATEGOR'].value_counts())
# Out:
# Public open space         25690
# Restricted public land    11423
# Private open space         1697
# Name: OS_TYPE, dtype: int64
# Natural and semi-natural open space      10385
# Parks and gardens                         8423
# Transport reservations                    5923
# Recreation corridor                       4267
# Sportsfields and organised recreation     3183
# Services and utilities reserves           1850
# Government schools                        1538
# Conservation reserves                     1443
# Non-government schools                     853
# Tertiary institutions                      743
# Cemeteries                                 113
# Civic squares and promenades                83
# Public housing reserves                      6
# Name: OS_CATEGOR, dtype: int64
