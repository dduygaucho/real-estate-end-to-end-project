# %% [markdown]
# # Raw Preprocessing for Population Data

# %%
import pandas as pd

# %%
LANDING_DATA_DIR = "../../../data/landing"
RAW_DATA_DIR = "../../../data/raw"
CURATED_DATA_DIR = "../../../data/curated"

# %%
# Load in data
pop = pd.read_excel(io = f"{LANDING_DATA_DIR}/population.xlsx", 
                    sheet_name = "Table 1", skiprows = 7)

# %% [markdown]
# ## Remove Unnecessary Columns
# **Columns to remove:**
# - `S/T code`
# - `GCCSA code`
# - `GCCSA name`
# - `SA4 code`
# - `SA4 name`
# - `SA3 code`
# - `SA3 name`

# %%
# Remove specified columns
pop.drop(columns = ["S/T code", "GCCSA code", "GCCSA name", "SA4 code", 
                    "SA4 name", "SA3 code", "SA3 name"], inplace = True)

# %% [markdown]
# ## Rename Columns for Year

# %%
# Rename columns for each year
rename_dict = {"no.": "2001", "no..1": "2002", "no..2": "2003", "no..3": "2004",
               "no..4": "2005", "no..5": "2006", "no..6": "2007", 
               "no..7": "2008", "no..8": "2009", "no..9": "2010", 
               "no..10": "2011", "no..11": "2012", "no..12": "2013",
               "no..13": "2014", "no..14": "2015", "no..15": "2016", 
               "no..16": "2017", "no..17": "2018", "no..18": "2019",
               "no..19": "2020", "no..20": "2021", "no..21": "2022",}
pop.rename(columns = rename_dict, inplace = True)

# %% [markdown]
# ## Remove Rows wth NAs

# %%
# Number of NA values per column
pop.isna().sum()
# Out:
# S/T name    8
# SA2 code    8
# SA2 name    7
# 2001        7
# 2002        7
# 2003        7
# 2004        7
# 2005        7
# 2006        7
# 2007        7
# 2008        7
# 2009        7
# 2010        7
# 2011        7
# 2012        7
# 2013        7
# 2014        7
# 2015        7
# 2016        7
# 2017        7
# 2018        7
# 2019        7
# 2020        7
# 2021        7
# 2022        7
# dtype: int64

# %%
# Create a boolean mask for NA values
na = pop.isna().any(axis=1)

# Filter the dataframe using the boolean mask
rows_with_na = pop[na].index.tolist()

# show rows with NA values
pop.iloc[rows_with_na, :]
# Out:
#      S/T name  SA2 code         SA2 name        2001        2002        2003  \
# 0         NaN       NaN              NaN         NaN         NaN         NaN
# 2455      NaN       NaN              NaN         NaN         NaN         NaN
# 2456      NaN       NaN  TOTAL AUSTRALIA  19274701.0  19495210.0  19720737.0
# 2457      NaN       NaN              NaN         NaN         NaN         NaN
# 2458      NaN       NaN              NaN         NaN         NaN         NaN
# 2459      NaN       NaN              NaN         NaN         NaN         NaN
# 2460      NaN       NaN              NaN         NaN         NaN         NaN
# 2461      NaN       NaN              NaN         NaN         NaN         NaN
#
#             2004        2005        2006        2007  ...        2013  \
# 0            NaN         NaN         NaN         NaN  ...         NaN
# 2455         NaN         NaN         NaN         NaN  ...         NaN
# 2456  19932722.0  20176844.0  20450966.0  20827622.0  ...  23128129.0
# 2457         NaN         NaN         NaN         NaN  ...         NaN
# 2458         NaN         NaN         NaN         NaN  ...         NaN
# 2459         NaN         NaN         NaN         NaN  ...         NaN
# 2460         NaN         NaN         NaN         NaN  ...         NaN
# 2461         NaN         NaN         NaN         NaN  ...         NaN
#
#             2014        2015        2016        2017        2018        2019  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 2455         NaN         NaN         NaN         NaN         NaN         NaN
# 2456  23475686.0  23815995.0  24190907.0  24594202.0  24966643.0  25340217.0
# 2457         NaN         NaN         NaN         NaN         NaN         NaN
# 2458         NaN         NaN         NaN         NaN         NaN         NaN
# 2459         NaN         NaN         NaN         NaN         NaN         NaN
# 2460         NaN         NaN         NaN         NaN         NaN         NaN
# 2461         NaN         NaN         NaN         NaN         NaN         NaN
#
#             2020        2021        2022
# 0            NaN         NaN         NaN
# 2455         NaN         NaN         NaN
# 2456  25655289.0  25688079.0  25996144.0
# 2457         NaN         NaN         NaN
# 2458         NaN         NaN         NaN
# 2459         NaN         NaN         NaN
# 2460         NaN         NaN         NaN
# 2461         NaN         NaN         NaN
#
# [8 rows x 25 columns]

# %%
# Remove all rows with NAs
pop.drop(index = rows_with_na, inplace = True)

# %%
# Check that NA removal was successful
pop.isna().sum()
# Out:
# S/T name    0
# SA2 code    0
# SA2 name    0
# 2001        0
# 2002        0
# 2003        0
# 2004        0
# 2005        0
# 2006        0
# 2007        0
# 2008        0
# 2009        0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# 2014        0
# 2015        0
# 2016        0
# 2017        0
# 2018        0
# 2019        0
# 2020        0
# 2021        0
# 2022        0
# dtype: int64

# %% [markdown]
# ## Data Type Conversion

# %%
# Map column name to new data type in dictionary
convert_dict = {}

for col_num in range(3, len(pop.columns)):
    convert_dict[pop.columns[col_num]] = "int"

# Convert datatypes
pop = pop.astype(convert_dict)

# %%
pop.head()
# Out:
#           S/T name     SA2 code                         SA2 name  2001   2002  \
# 1  New South Wales  101021007.0                        Braidwood  2760   2811
# 2  New South Wales  101021008.0                          Karabar  9129   9199
# 3  New South Wales  101021009.0                       Queanbeyan  9717   9513
# 4  New South Wales  101021010.0                Queanbeyan - East  3925   4073
# 5  New South Wales  101021012.0  Queanbeyan West - Jerrabomberra  9425  10257
#
#     2003   2004   2005   2006   2007  ...   2013   2014   2015   2016   2017  \
# 1   2835   2844   2847   2965   3102  ...   3685   3762   3849   3950   4039
# 2   9263   9277   9209   9212   9033  ...   8848   8731   8603   8531   8526
# 3   9522   9400   9595   9682   9793  ...  11050  11199  11213  11230  11355
# 4   4219   4218   4187   4319   4459  ...   4983   4967   4961   4970   5013
# 5  11085  11549  12046  12358  12622  ...  13210  13193  13164  13150  13083
#
#     2018   2019   2020   2021   2022
# 1   4140   4211   4273   4330   4364
# 2   8507   8488   8519   8546   8535
# 3  11447  11450  11437  11370  11376
# 4   5072   5117   5077   5093   5093
# 5  13008  12935  12796  12743  12775
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Output to CSV in Raw data directory

# %%
pop.to_csv(f"{RAW_DATA_DIR}/population.csv", index = False)
